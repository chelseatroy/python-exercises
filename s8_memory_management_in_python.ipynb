# %% [markdown]
# ### Two flavors of memory management
#
# 1. Reference Counting
# 2. Generational Garbage Collection
#
# ### Reference Counting

# %%
import sys

greeting = "Hello!"
whisper_greeting = greeting.lower()
sys.getrefcount(greeting)
# Out:
# 3

# %% [markdown]
# ### Problem with Reference Counting: Reference Cycles

# %%
listo = []
listo.append(listo)

memory_address_of_listo = id(listo)
print(memory_address_of_listo)
# Out:
# 4419692992

# %%
del listo

# %%
# Gives an error because the name has been deleted, but...
sys.getrefcount(listo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Gives an error because the name has been deleted, but...
# ----> 2 sys.getrefcount(listo)
#
# NameError: name 'listo' is not defined

# %%
import ctypes

# There's still a reference to its memory address!
ctypes.c_long.from_address(memory_address_of_listo)
# Out:
# c_long(2)

# %% [markdown]
# ### Generational Garbage Collection

# %%
import gc

gc.get_threshold()
# Out:
# (700, 10, 10)

# %%
gc.get_count()
# Out:
# (320, 1, 0)

# %%
gc.collect()
# Out:
# 478

# %%
gc.get_count()
# Out:
# (88, 0, 0)

# %%
print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))
# Out:
# True

# %%
#Now let's check the memory address from the deleted instance name again
ctypes.c_long.from_address(memory_address_of_listo)
# Out:
# c_long(1)

# %% [markdown]
# ### Bonus things to try

# %%
sys._debugmallocstats()
# Out:
# Small block threshold = 512, in 32 size classes.
#
# class   size   num pools   blocks in use  avail blocks
# -----   ----   ---------   -------------  ------------
#     0     16          17            4129           172
#     1     32         229           28591           263
#     2     48         648           52868          1564
#     3     64        2252          138314          3562
#     4     80        1289           63830           620
#     5     96         443           18419           187
#     6    112         244            8765            19
#     7    128         202            6212            50
#     8    144         788           22029            35
#     9    160         106            2609            41
#    10    176        1453           33302           117
#    11    192          69            1413            36
#    12    208          78            1474             8
#    13    224         126            2267             1
#    14    240          51             815             1
#    15    256          39             574            11
#    16    272          38             522            10
#    17    288          27             369             9
#    18    304         245            3181             4
#    19    320          31             367             5
#    20    336          25             293             7
#    21    352          22             234             8
#    22    368          21             228             3
#    23    384          23             220            10
#    24    400          29             281             9
#    25    416          56             500             4
#    26    432          68             605             7
#    27    448          60             534             6
#    28    464          48             382             2
#    29    480          58             457             7
#    30    496          43             336             8
#    31    512          61             421             6
#
# # arenas allocated total           =                  140
# # arenas reclaimed                 =                    0
# # arenas highwater mark            =                  140
# # arenas allocated current         =                  140
# 140 arenas * 262144 bytes/arena    =           36,700,160
#
# # bytes in allocated blocks        =           35,182,912
# # bytes in available blocks        =              474,880
# 71 unused pools * 4096 bytes       =              290,816
# # bytes lost to pool headers       =              426,672
# # bytes lost to quantization       =              324,880
# # bytes lost to arena alignment    =                    0
# Total                              =           36,700,160
#
#            59 free PyDictObjects * 48 bytes each =                2,832
#            4 free PyFloatObjects * 24 bytes each =                   96
#           2 free PyFrameObjects * 368 bytes each =                  736
#            35 free PyListObjects * 40 bytes each =                1,400
#   10 free 1-sized PyTupleObjects * 32 bytes each =                  320
#   43 free 2-sized PyTupleObjects * 40 bytes each =                1,720
#    4 free 3-sized PyTupleObjects * 48 bytes each =                  192
#    2 free 4-sized PyTupleObjects * 56 bytes each =                  112
#    2 free 5-sized PyTupleObjects * 64 bytes each =                  128
#    1 free 6-sized PyTupleObjects * 72 bytes each =                   72
#    1 free 7-sized PyTupleObjects * 80 bytes each =                   80
#    1 free 8-sized PyTupleObjects * 88 bytes each =                   88
#    1 free 9-sized PyTupleObjects * 96 bytes each =                   96
#  0 free 10-sized PyTupleObjects * 104 bytes each =                    0
#  0 free 11-sized PyTupleObjects * 112 bytes each =                    0
#  0 free 12-sized PyTupleObjects * 120 bytes each =                    0
#  0 free 13-sized PyTupleObjects * 128 bytes each =                    0
#  0 free 14-sized PyTupleObjects * 136 bytes each =                    0
#  0 free 15-sized PyTupleObjects * 144 bytes each =                    0
#  0 free 16-sized PyTupleObjects * 152 bytes each =                    0
#  0 free 17-sized PyTupleObjects * 160 bytes each =                    0
#  0 free 18-sized PyTupleObjects * 168 bytes each =                    0
#  0 free 19-sized PyTupleObjects * 176 bytes each =                    0

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import gc\n\ngc.get_threshold()',
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import gc\n\ngc.get_threshold()',
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'sys._debugmallocstats() ',
#   'globals()'],
#  '_oh': {1: 3,
#   5: c_long(0),
#   6: (700, 10, 10),
#   7: (83, 0, 10),
#   8: 514,
#   9: (84, 0, 0),
#   10: c_long(0),
#   11: (146, 0, 0),
#   12: 0,
#   13: (86, 0, 0),
#   14: c_long(0),
#   16: c_long(0),
#   17: 3,
#   21: c_long(0),
#   22: c_long(0),
#   23: 3,
#   27: c_long(7),
#   28: (700, 10, 10),
#   29: (415, 4, 0),
#   30: 972,
#   31: (84, 0, 0),
#   32: c_long(7),
#   33: c_long(7),
#   35: c_long(7)},
#  '_dh': [PosixPath('/Users/chelseatroy/teaching/materials/move_me')],
#  'In': ['',
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import gc\n\ngc.get_threshold()',
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import gc\n\ngc.get_threshold()',
#   'gc.get_count()',
#   'gc.collect()',
#   'gc.get_count()',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#   "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#   'sys._debugmallocstats() ',
#   'globals()'],
#  'Out': {1: 3,
#   5: c_long(0),
#   6: (700, 10, 10),
#   7: (83, 0, 10),
#   8: 514,
#   9: (84, 0, 0),
#   10: c_long(0),
#   11: (146, 0, 0),
#   12: 0,
#   13: (86, 0, 0),
#   14: c_long(0),
#   16: c_long(0),
#   17: 3,
#   21: c_long(0),
#   22: c_long(0),
#   23: 3,
#   27: c_long(7),
#   28: (700, 10, 10),
#   29: (415, 4, 0),
#   30: 972,
#   31: (84, 0, 0),
#   32: c_long(7),
#   33: c_long(7),
#   35: c_long(7)},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107558dc0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x107569af0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x107569af0>,
#  'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': c_long(7),
#  '__': c_long(7),
#  '___': c_long(7),
#  '__session__': '/Users/chelseatroy/teaching/materials/move_me/Memory_Management_in_Python.ipynb',
#  '_i': 'sys._debugmallocstats() ',
#  '_ii': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_iii': 'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#  '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#  'sys': <module 'sys' (built-in)>,
#  'greeting': 'Hello!',
#  'whisper_greeting': 'hello!',
#  '_1': 3,
#  '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#  'memory_address_of_listo': 4418891392,
#  '_i3': 'del listo',
#  '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#  '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  'ctypes': <module 'ctypes' from '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py'>,
#  '_5': c_long(0),
#  '_i6': 'import gc\n\ngc.get_threshold()',
#  'gc': <module 'gc' (built-in)>,
#  '_6': (700, 10, 10),
#  '_i7': 'gc.get_count()',
#  '_7': (83, 0, 10),
#  '_i8': 'gc.collect()',
#  '_8': 514,
#  '_i9': 'gc.get_count()',
#  '_9': (84, 0, 0),
#  '_i10': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_10': c_long(0),
#  '_i11': 'gc.get_count()',
#  '_11': (146, 0, 0),
#  '_i12': 'gc.collect()',
#  '_12': 0,
#  '_i13': 'gc.get_count()',
#  '_13': (86, 0, 0),
#  '_i14': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_14': c_long(0),
#  '_i15': 'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#  '_i16': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_16': c_long(0),
#  '_i17': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#  '_17': 3,
#  '_i18': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#  '_i19': 'del listo',
#  '_i20': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#  '_i21': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_21': c_long(0),
#  '_i22': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_22': c_long(0),
#  '_i23': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#  '_23': 3,
#  '_i24': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#  '_i25': 'del listo',
#  '_i26': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#  '_i27': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_27': c_long(7),
#  '_i28': 'import gc\n\ngc.get_threshold()',
#  '_28': (700, 10, 10),
#  '_i29': 'gc.get_count()',
#  '_29': (415, 4, 0),
#  '_i30': 'gc.collect()',
#  '_30': 972,
#  '_i31': 'gc.get_count()',
#  '_31': (84, 0, 0),
#  '_i32': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_32': c_long(7),
#  '_i33': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_33': c_long(7),
#  '_i34': 'print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))',
#  '_i35': "#Now let's check the memory address from the deleted instance name again\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_35': c_long(7),
#  '_i36': 'sys._debugmallocstats() ',
#  '_i37': 'globals()'}
