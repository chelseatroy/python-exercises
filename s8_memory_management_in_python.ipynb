# %% [markdown]
# ### Two flavors of memory management
#
# 1. Reference Counting
# 2. Generational Garbage Collection
#
# ### Reference Counting

# %%
import sys

greeting = "Hello!"
whisper_greeting = greeting.lower()
sys.getrefcount(greeting)
# Out:
# 3

# %% [markdown]
# ### Problem with Reference Counting: Reference Cycles

# %%
listo = []
listo.append(listo)

memory_address_of_listo = id(listo)
print(memory_address_of_listo)
# Out:
# 4405948288

# %%
del listo

# %%
# Gives an error because the name has been deleted, but...
sys.getrefcount(listo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Gives an error because the name has been deleted, but...
# ----> 2 sys.getrefcount(listo)
#
# NameError: name 'listo' is not defined

# %%
import ctypes

# There's still a reference to its memory address!
ctypes.c_long.from_address(memory_address_of_listo)
# Out:
# c_long(2)

# %% [markdown]
# ### Generational Garbage Collection

# %%
import gc

gc.get_threshold()
# Out:
# (700, 10, 10)

# %%
gc.get_count()
# Out:
# (325, 1, 0)

# %%
(gc.get_referrers(memory_address_of_listo))[3]
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#   'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#   'del listo',
#   '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#   "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#   'import gc\n\ngc.get_threshold()',
#   'gc.get_count()',
#   '(gc.get_referrers(memory_address_of_listo))',
#   'len((gc.get_referrers(memory_address_of_listo)))',
#   '(gc.get_referrers(memory_address_of_listo))',
#   '(gc.get_referrers(memory_address_of_listo))[2]',
#   '(gc.get_referrers(memory_address_of_listo))[1]',
#   '(gc.get_referrers(memory_address_of_listo))[0]',
#   '(gc.get_referrers(memory_address_of_listo))[3]'],
#  '_oh': {1: 3,
#   5: c_long(1),
#   6: (700, 10, 10),
#   7: (325, 1, 0),
#   8: [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#     '_obj': 4405948288},
#    {'__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     '_oh': {...},
#     '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#     'In': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     'Out': {...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#     '_': {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     '__': {...},
#     '___': {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#     '_i': '(gc.get_referrers(memory_address_of_listo))[0]',
#     '_ii': '(gc.get_referrers(memory_address_of_listo))[1]',
#     '_iii': '(gc.get_referrers(memory_address_of_listo))[2]',
#     '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'sys': <module 'sys' (built-in)>,
#     'greeting': 'Hello!',
#     'whisper_greeting': 'hello!',
#     '_1': 3,
#     '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'memory_address_of_listo': 4405948288,
#     '_i3': 'del listo',
#     '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#     '_5': c_long(1),
#     '_i6': 'import gc\n\ngc.get_threshold()',
#     'gc': <module 'gc' (built-in)>,
#     '_6': (700, 10, 10),
#     '_i7': 'gc.get_count()',
#     '_7': (325, 1, 0),
#     '_i8': '(gc.get_referrers(memory_address_of_listo))',
#     '_8': [...],
#     '_i9': 'len((gc.get_referrers(memory_address_of_listo)))',
#     '_9': 4,
#     '_i10': '(gc.get_referrers(memory_address_of_listo))',
#     '_10': [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#       '_obj': 4405948288},
#      {...},
#      {'__name__': '__main__',
#       '__doc__': 'Automatically created module for IPython interactive environment',
#       '__package__': None,
#       '__loader__': None,
#       '__spec__': None,
#       '__builtin__': <module 'builtins' (built-in)>,
#       '__builtins__': <module 'builtins' (built-in)>,
#       '_ih': ['',
#        'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#        'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#        'del listo',
#        '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#        "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#        'import gc\n\ngc.get_threshold()',
#        'gc.get_count()',
#        '(gc.get_referrers(memory_address_of_listo))',
#        'len((gc.get_referrers(memory_address_of_listo)))',
#        '(gc.get_referrers(memory_address_of_listo))',
#        '(gc.get_referrers(memory_address_of_listo))[2]',
#        '(gc.get_referrers(memory_address_of_listo))[1]',
#        '(gc.get_referrers(memory_address_of_listo))[0]',
#        '(gc.get_referrers(memory_address_of_listo))[3]'],
#       '_oh': {...},
#       '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#       'In': ['',
#        'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#        'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#        'del listo',
#        '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#        "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#        'import gc\n\ngc.get_threshold()',
#        'gc.get_count()',
#        '(gc.get_referrers(memory_address_of_listo))',
#        'len((gc.get_referrers(memory_address_of_listo)))',
#        '(gc.get_referrers(memory_address_of_listo))',
#        '(gc.get_referrers(memory_address_of_listo))[2]',
#        '(gc.get_referrers(memory_address_of_listo))[1]',
#        '(gc.get_referrers(memory_address_of_listo))[0]',
#        '(gc.get_referrers(memory_address_of_listo))[3]'],
#       'Out': {...},
#       'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#       'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#       'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#       'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#       '_': (325, 1, 0),
#       '__': (700, 10, 10),
#       '___': c_long(1),
#       '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#       '_i': 'import gc\n\ngc.get_threshold()',
#       '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'sys': <module 'sys' (built-in)>,
#       'greeting': 'Hello!',
#       'whisper_greeting': 'hello!',
#       '_1': 3,
#       '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'memory_address_of_listo': 4405948288,
#       '_i3': 'del listo',
#       '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#       '_5': c_long(1),
#       '_i6': 'import gc\n\ngc.get_threshold()',
#       'gc': <module 'gc' (built-in)>,
#       '_6': (700, 10, 10),
#       '_i7': 'gc.get_count()',
#       '_7': (325, 1, 0)},
#      {...}],
#     '_i11': '(gc.get_referrers(memory_address_of_listo))[2]',
#     '_11': {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     '_i12': '(gc.get_referrers(memory_address_of_listo))[1]',
#     '_12': {...},
#     '_i13': '(gc.get_referrers(memory_address_of_listo))[0]',
#     '_13': {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     '_i14': '(gc.get_referrers(memory_address_of_listo))[3]'},
#    {'__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     '_oh': {...},
#     '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#     'In': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     'Out': {...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#     '_': (325, 1, 0),
#     '__': (700, 10, 10),
#     '___': c_long(1),
#     '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#     '_i': 'import gc\n\ngc.get_threshold()',
#     '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'sys': <module 'sys' (built-in)>,
#     'greeting': 'Hello!',
#     'whisper_greeting': 'hello!',
#     '_1': 3,
#     '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'memory_address_of_listo': 4405948288,
#     '_i3': 'del listo',
#     '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#     '_5': c_long(1),
#     '_i6': 'import gc\n\ngc.get_threshold()',
#     'gc': <module 'gc' (built-in)>,
#     '_6': (700, 10, 10),
#     '_i7': 'gc.get_count()',
#     '_7': (325, 1, 0)},
#    {...}],
#   9: 4,
#   10: [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#     '_obj': 4405948288},
#    {'__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     '_oh': {...},
#     '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#     'In': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     'Out': {...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#     '_': {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     '__': {...},
#     '___': {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#     '_i': '(gc.get_referrers(memory_address_of_listo))[0]',
#     '_ii': '(gc.get_referrers(memory_address_of_listo))[1]',
#     '_iii': '(gc.get_referrers(memory_address_of_listo))[2]',
#     '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'sys': <module 'sys' (built-in)>,
#     'greeting': 'Hello!',
#     'whisper_greeting': 'hello!',
#     '_1': 3,
#     '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'memory_address_of_listo': 4405948288,
#     '_i3': 'del listo',
#     '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#     '_5': c_long(1),
#     '_i6': 'import gc\n\ngc.get_threshold()',
#     'gc': <module 'gc' (built-in)>,
#     '_6': (700, 10, 10),
#     '_i7': 'gc.get_count()',
#     '_7': (325, 1, 0),
#     '_i8': '(gc.get_referrers(memory_address_of_listo))',
#     '_8': [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#       '_obj': 4405948288},
#      {...},
#      {'__name__': '__main__',
#       '__doc__': 'Automatically created module for IPython interactive environment',
#       '__package__': None,
#       '__loader__': None,
#       '__spec__': None,
#       '__builtin__': <module 'builtins' (built-in)>,
#       '__builtins__': <module 'builtins' (built-in)>,
#       '_ih': ['',
#        'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#        'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#        'del listo',
#        '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#        "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#        'import gc\n\ngc.get_threshold()',
#        'gc.get_count()',
#        '(gc.get_referrers(memory_address_of_listo))',
#        'len((gc.get_referrers(memory_address_of_listo)))',
#        '(gc.get_referrers(memory_address_of_listo))',
#        '(gc.get_referrers(memory_address_of_listo))[2]',
#        '(gc.get_referrers(memory_address_of_listo))[1]',
#        '(gc.get_referrers(memory_address_of_listo))[0]',
#        '(gc.get_referrers(memory_address_of_listo))[3]'],
#       '_oh': {...},
#       '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#       'In': ['',
#        'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#        'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#        'del listo',
#        '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#        "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#        'import gc\n\ngc.get_threshold()',
#        'gc.get_count()',
#        '(gc.get_referrers(memory_address_of_listo))',
#        'len((gc.get_referrers(memory_address_of_listo)))',
#        '(gc.get_referrers(memory_address_of_listo))',
#        '(gc.get_referrers(memory_address_of_listo))[2]',
#        '(gc.get_referrers(memory_address_of_listo))[1]',
#        '(gc.get_referrers(memory_address_of_listo))[0]',
#        '(gc.get_referrers(memory_address_of_listo))[3]'],
#       'Out': {...},
#       'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#       'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#       'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#       'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#       '_': (325, 1, 0),
#       '__': (700, 10, 10),
#       '___': c_long(1),
#       '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#       '_i': 'import gc\n\ngc.get_threshold()',
#       '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'sys': <module 'sys' (built-in)>,
#       'greeting': 'Hello!',
#       'whisper_greeting': 'hello!',
#       '_1': 3,
#       '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'memory_address_of_listo': 4405948288,
#       '_i3': 'del listo',
#       '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#       '_5': c_long(1),
#       '_i6': 'import gc\n\ngc.get_threshold()',
#       'gc': <module 'gc' (built-in)>,
#       '_6': (700, 10, 10),
#       '_i7': 'gc.get_count()',
#       '_7': (325, 1, 0)},
#      {...}],
#     '_i9': 'len((gc.get_referrers(memory_address_of_listo)))',
#     '_9': 4,
#     '_i10': '(gc.get_referrers(memory_address_of_listo))',
#     '_10': [...],
#     '_i11': '(gc.get_referrers(memory_address_of_listo))[2]',
#     '_11': {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     '_i12': '(gc.get_referrers(memory_address_of_listo))[1]',
#     '_12': {...},
#     '_i13': '(gc.get_referrers(memory_address_of_listo))[0]',
#     '_13': {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     '_i14': '(gc.get_referrers(memory_address_of_listo))[3]'},
#    {'__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     '_oh': {...},
#     '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#     'In': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     'Out': {...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#     '_': (325, 1, 0),
#     '__': (700, 10, 10),
#     '___': c_long(1),
#     '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#     '_i': 'import gc\n\ngc.get_threshold()',
#     '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'sys': <module 'sys' (built-in)>,
#     'greeting': 'Hello!',
#     'whisper_greeting': 'hello!',
#     '_1': 3,
#     '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'memory_address_of_listo': 4405948288,
#     '_i3': 'del listo',
#     '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#     '_5': c_long(1),
#     '_i6': 'import gc\n\ngc.get_threshold()',
#     'gc': <module 'gc' (built-in)>,
#     '_6': (700, 10, 10),
#     '_i7': 'gc.get_count()',
#     '_7': (325, 1, 0)},
#    {...}],
#   11: {'__name__': '__main__',
#    '__doc__': 'Automatically created module for IPython interactive environment',
#    '__package__': None,
#    '__loader__': None,
#    '__spec__': None,
#    '__builtin__': <module 'builtins' (built-in)>,
#    '__builtins__': <module 'builtins' (built-in)>,
#    '_ih': ['',
#     'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'del listo',
#     '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'import gc\n\ngc.get_threshold()',
#     'gc.get_count()',
#     '(gc.get_referrers(memory_address_of_listo))',
#     'len((gc.get_referrers(memory_address_of_listo)))',
#     '(gc.get_referrers(memory_address_of_listo))',
#     '(gc.get_referrers(memory_address_of_listo))[2]',
#     '(gc.get_referrers(memory_address_of_listo))[1]',
#     '(gc.get_referrers(memory_address_of_listo))[0]',
#     '(gc.get_referrers(memory_address_of_listo))[3]'],
#    '_oh': {...},
#    '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#    'In': ['',
#     'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'del listo',
#     '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'import gc\n\ngc.get_threshold()',
#     'gc.get_count()',
#     '(gc.get_referrers(memory_address_of_listo))',
#     'len((gc.get_referrers(memory_address_of_listo)))',
#     '(gc.get_referrers(memory_address_of_listo))',
#     '(gc.get_referrers(memory_address_of_listo))[2]',
#     '(gc.get_referrers(memory_address_of_listo))[1]',
#     '(gc.get_referrers(memory_address_of_listo))[0]',
#     '(gc.get_referrers(memory_address_of_listo))[3]'],
#    'Out': {...},
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#    'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#    'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#    'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#    '_': (325, 1, 0),
#    '__': (700, 10, 10),
#    '___': c_long(1),
#    '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#    '_i': 'import gc\n\ngc.get_threshold()',
#    '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#    '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#    '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#    'sys': <module 'sys' (built-in)>,
#    'greeting': 'Hello!',
#    'whisper_greeting': 'hello!',
#    '_1': 3,
#    '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#    'memory_address_of_listo': 4405948288,
#    '_i3': 'del listo',
#    '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#    '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#    'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#    '_5': c_long(1),
#    '_i6': 'import gc\n\ngc.get_threshold()',
#    'gc': <module 'gc' (built-in)>,
#    '_6': (700, 10, 10),
#    '_i7': 'gc.get_count()',
#    '_7': (325, 1, 0)},
#   12: {'__name__': '__main__',
#    '__doc__': 'Automatically created module for IPython interactive environment',
#    '__package__': None,
#    '__loader__': None,
#    '__spec__': None,
#    '__builtin__': <module 'builtins' (built-in)>,
#    '__builtins__': <module 'builtins' (built-in)>,
#    '_ih': ['',
#     'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'del listo',
#     '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
# ...
#    '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#    '_i': '(gc.get_referrers(memory_address_of_listo))[0]',
#    '_ii': '(gc.get_referrers(memory_address_of_listo))[1]',
#    '_iii': '(gc.get_referrers(memory_address_of_listo))[2]',
#    '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#    'sys': <module 'sys' (built-in)>,
#    'greeting': 'Hello!',
#    'whisper_greeting': 'hello!',
#    '_1': 3,
#    '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#    'memory_address_of_listo': 4405948288,
#    '_i3': 'del listo',
#    '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#    '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#    'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#    '_5': c_long(1),
#    '_i6': 'import gc\n\ngc.get_threshold()',
#    'gc': <module 'gc' (built-in)>,
#    '_6': (700, 10, 10),
#    '_i7': 'gc.get_count()',
#    '_7': (325, 1, 0),
#    '_i8': '(gc.get_referrers(memory_address_of_listo))',
#    '_8': [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     {...},
#     {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     {...}],
#    '_i9': 'len((gc.get_referrers(memory_address_of_listo)))',
#    '_9': 4,
#    '_i10': '(gc.get_referrers(memory_address_of_listo))',
#    '_10': [{'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#      '_obj': 4405948288},
#     {...},
#     {'__name__': '__main__',
#      '__doc__': 'Automatically created module for IPython interactive environment',
#      '__package__': None,
#      '__loader__': None,
#      '__spec__': None,
#      '__builtin__': <module 'builtins' (built-in)>,
#      '__builtins__': <module 'builtins' (built-in)>,
#      '_ih': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      '_oh': {...},
#      '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#      'In': ['',
#       'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#       'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#       'del listo',
#       '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#       "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#       'import gc\n\ngc.get_threshold()',
#       'gc.get_count()',
#       '(gc.get_referrers(memory_address_of_listo))',
#       'len((gc.get_referrers(memory_address_of_listo)))',
#       '(gc.get_referrers(memory_address_of_listo))',
#       '(gc.get_referrers(memory_address_of_listo))[2]',
#       '(gc.get_referrers(memory_address_of_listo))[1]',
#       '(gc.get_referrers(memory_address_of_listo))[0]',
#       '(gc.get_referrers(memory_address_of_listo))[3]'],
#      'Out': {...},
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#      'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      '_': (325, 1, 0),
#      '__': (700, 10, 10),
#      '___': c_long(1),
#      '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#      '_i': 'import gc\n\ngc.get_threshold()',
#      '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'sys': <module 'sys' (built-in)>,
#      'greeting': 'Hello!',
#      'whisper_greeting': 'hello!',
#      '_1': 3,
#      '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'memory_address_of_listo': 4405948288,
#      '_i3': 'del listo',
#      '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#      '_5': c_long(1),
#      '_i6': 'import gc\n\ngc.get_threshold()',
#      'gc': <module 'gc' (built-in)>,
#      '_6': (700, 10, 10),
#      '_i7': 'gc.get_count()',
#      '_7': (325, 1, 0)},
#     {...}],
#    '_i11': '(gc.get_referrers(memory_address_of_listo))[2]',
#    '_11': {'__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     '_oh': {...},
#     '_dh': [PosixPath('/Users/chelseatroy/teaching/python-exercises')],
#     'In': ['',
#      'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#      'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#      'del listo',
#      '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#      "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#      'import gc\n\ngc.get_threshold()',
#      'gc.get_count()',
#      '(gc.get_referrers(memory_address_of_listo))',
#      'len((gc.get_referrers(memory_address_of_listo)))',
#      '(gc.get_referrers(memory_address_of_listo))',
#      '(gc.get_referrers(memory_address_of_listo))[2]',
#      '(gc.get_referrers(memory_address_of_listo))[1]',
#      '(gc.get_referrers(memory_address_of_listo))[0]',
#      '(gc.get_referrers(memory_address_of_listo))[3]'],
#     'Out': {...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#     'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#     '_': (325, 1, 0),
#     '__': (700, 10, 10),
#     '___': c_long(1),
#     '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#     '_i': 'import gc\n\ngc.get_threshold()',
#     '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#     'sys': <module 'sys' (built-in)>,
#     'greeting': 'Hello!',
#     'whisper_greeting': 'hello!',
#     '_1': 3,
#     '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#     'memory_address_of_listo': 4405948288,
#     '_i3': 'del listo',
#     '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#     '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#     'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#     '_5': c_long(1),
#     '_i6': 'import gc\n\ngc.get_threshold()',
#     'gc': <module 'gc' (built-in)>,
#     '_6': (700, 10, 10),
#     '_i7': 'gc.get_count()',
#     '_7': (325, 1, 0)},
#    '_i12': '(gc.get_referrers(memory_address_of_listo))[1]',
#    '_12': {...},
#    '_i13': '(gc.get_referrers(memory_address_of_listo))[0]',
#    '_13': {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#     '_obj': 4405948288},
#    '_i14': '(gc.get_referrers(memory_address_of_listo))[3]'},
#   13: {'_inference_state': <jedi.inference.InferenceState at 0x106de78b0>,
#    '_obj': 4405948288}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10692cbb0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10692d7e0>,
#  'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': (325, 1, 0),
#  '__': (700, 10, 10),
#  '___': c_long(1),
#  '__session__': '/Users/chelseatroy/teaching/python-exercises/s8_memory_management_in_python.ipynb',
#  '_i': 'import gc\n\ngc.get_threshold()',
#  '_ii': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  '_iii': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#  '_i1': 'import sys\n\ngreeting = "Hello!"\nwhisper_greeting = greeting.lower()\nsys.getrefcount(greeting)',
#  'sys': <module 'sys' (built-in)>,
#  'greeting': 'Hello!',
#  'whisper_greeting': 'hello!',
#  '_1': 3,
#  '_i2': 'listo = []\nlisto.append(listo)\n\nmemory_address_of_listo = id(listo)\nprint(memory_address_of_listo)',
#  'memory_address_of_listo': 4405948288,
#  '_i3': 'del listo',
#  '_i4': '# Gives an error because the name has been deleted, but...\nsys.getrefcount(listo)',
#  '_i5': "import ctypes\n\n# There's still a reference to its memory address!\nctypes.c_long.from_address(memory_address_of_listo)",
#  'ctypes': <module 'ctypes' from '/Users/chelseatroy/.pyenv/versions/3.10.8/lib/python3.10/ctypes/__init__.py'>,
#  '_5': c_long(1),
#  '_i6': 'import gc\n\ngc.get_threshold()',
#  'gc': <module 'gc' (built-in)>,
#  '_6': (700, 10, 10),
#  '_i7': 'gc.get_count()',
#  '_7': (325, 1, 0)}

# %%
gc.collect()
# Out:
# 667

# %%
gc.get_count()
# Out:
# (87, 0, 0)

# %%
print(any(id(obj) == memory_address_of_listo for obj in gc.get_objects()))
# Out:
# True

# %%
#Now let's check the memory address from the deleted instance name again
ctypes.c_long.from_address(memory_address_of_listo)
# Out:
# c_long(1)

# %% [markdown]
# ### Bonus things to try

# %%
sys._debugmallocstats()
# Out:
# Small block threshold = 512, in 32 size classes.
#
# class   size   num pools   blocks in use  avail blocks
# -----   ----   ---------   -------------  ------------
#     0     16           5            4616           489
#     1     32          91           46054           356
#     2     48         229           77081           779
#     3     64         933          198604         39311
#     4     80         447           88186          3002
#     5     96         128           21111           649
#     6    112          70           10124            26
#     7    128          60            7496           124
#     8    144         221           24108           865
#     9    160          39            3541           437
#    10    176         394           35301           947
#    11    192          21            1737            48
#    12    208          16            1231            17
#    13    224          46            3272            40
#    14    240          12             778            38
#    15    256          11             665            28
#    16    272          10             553            47
#    17    288           9             446            58
#    18    304          63            3291            48
#    19    320           8             386            22
#    20    336           7             307            29
#    21    352           6             245            31
#    22    368           6             241            23
#    23    384           7             261            33
#    24    400          12             471             9
#    25    416          19             705            36
#    26    432          21             740            37
#    27    448          18             614            34
#    28    464          14             469            21
#    29    480          14             448            28
#    30    496          13             406            10
#    31    512          25             769             6
#
# # arenas allocated total           =                   50
# # arenas reclaimed                 =                    0
# # arenas highwater mark            =                   50
# # arenas allocated current         =                   50
# 50 arenas * 1048576 bytes/arena    =           52,428,800
#
# # bytes in allocated blocks        =           44,948,912
# # bytes in available blocks        =            3,466,832
# 225 unused pools * 16384 bytes     =            3,686,400
# # bytes lost to pool headers       =              142,800
# # bytes lost to quantization       =              183,856
# # bytes lost to arena alignment    =                    0
# Total                              =           52,428,800
#
# arena map counts
# # arena map mid nodes              =                    1
# # arena map bot nodes              =                    2
#
# # bytes lost to arena map root     =                8,192
# # bytes lost to arena map mid      =                8,192
# # bytes lost to arena map bot      =                4,096
# Total                              =               20,480
#
#            55 free PyDictObjects * 48 bytes each =                2,640
#            5 free PyFloatObjects * 24 bytes each =                  120
#          33 free PyFrameObjects * 360 bytes each =               11,880
#            63 free PyListObjects * 40 bytes each =                2,520
#  173 free 1-sized PyTupleObjects * 32 bytes each =                5,536
#  213 free 2-sized PyTupleObjects * 40 bytes each =                8,520
#   49 free 3-sized PyTupleObjects * 48 bytes each =                2,352
#   62 free 4-sized PyTupleObjects * 56 bytes each =                3,472
#    3 free 5-sized PyTupleObjects * 64 bytes each =                  192
#    1 free 6-sized PyTupleObjects * 72 bytes each =                   72
#    1 free 7-sized PyTupleObjects * 80 bytes each =                   80
#    1 free 8-sized PyTupleObjects * 88 bytes each =                   88
#    1 free 9-sized PyTupleObjects * 96 bytes each =                   96
#  0 free 10-sized PyTupleObjects * 104 bytes each =                    0
#  0 free 11-sized PyTupleObjects * 112 bytes each =                    0
#  0 free 12-sized PyTupleObjects * 120 bytes each =                    0
#  0 free 13-sized PyTupleObjects * 128 bytes each =                    0
#  0 free 14-sized PyTupleObjects * 136 bytes each =                    0
#  1 free 15-sized PyTupleObjects * 144 bytes each =                  144
#  0 free 16-sized PyTupleObjects * 152 bytes each =                    0
#  0 free 17-sized PyTupleObjects * 160 bytes each =                    0
#  0 free 18-sized PyTupleObjects * 168 bytes each =                    0
#  0 free 19-sized PyTupleObjects * 176 bytes each =                    0

# %%
globals()
