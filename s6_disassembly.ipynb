# %%
import dis

# %% [markdown]
# ## The Stack

# %%
dis.dis("1+1")

# %%
def add_ones():
    return 1 + 1

dis.dis(add_ones)

# %%
def add_two_numbers(a, b):
    return a + b

dis.dis(add_two_numbers)

# %%
def add_three_numbers(a, b, c):
    traceback.print_stack()
    return a + b + c

dis.dis(add_three_numbers)

# %% [markdown]
# ## If

# %%
def equals_five(x):
    if x == 5:
        return True
    else:
        return False

dis.dis(equals_five)

# %% [markdown]
# ## Storing and loading names

# %%
def looping_sum(start, end, increment):
    result = 0
    for item in range(start, end, increment):
        result += item
    return result

dis.dis(looping_sum)

# %%
dis.dis(
"""
result = 0
for item in range(start, end, increment):
    result += item
"""
)

# %%
import time

start = time.perf_counter()
looping_sum(1, 10000000, 1)
end = time.perf_counter()

print(end - start)

# %%
import time

start = time.perf_counter()
result = 0
for item in range(1, 10000000, 1):
    result += item
print(result)
end = time.perf_counter()

print(end - start)

# %%
def loopy():
    x = []
    for i in range(0,10):
        x.append(i)
    return x

dis.dis(loopy)

# %%
def compy():
    x = [i for i in range(0,10)]
    return x

dis.dis(compy)

# %% [markdown]
# ## Is, by environment

# %%
def notebook_is():
    two_hundred_fifty_seven = 257
    two_hundred_fifty_seven_again = 257
    return two_hundred_fifty_seven is two_hundred_fifty_seven_again

# %%
notebook_is()

# %%
dis.dis(notebook_is)

# %%
two_hundred_fifty_seven = 257
two_hundred_fifty_seven_again = 257

two_hundred_fifty_seven is two_hundred_fifty_seven_again

# %%
dis.dis('''
two_hundred_fifty_seven = 257
two_hundred_fifty_seven_again = 257

two_hundred_fifty_seven is two_hundred_fifty_seven_again
''')

# %% [markdown]
# ## Resources:
#
#  - [dis documentation](https://docs.python.org/3/library/dis.html)
